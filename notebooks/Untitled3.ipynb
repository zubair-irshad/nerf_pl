# %%
import json
pose_file_path = '/home/zubairirshad/pd-api-py/scene_000000/scene_df083147fe8ca890d666527c3cd9f239e827828b.json'

with open(pose_file_path, "r") as read_content:
    data = json.load(read_content)
    
print(data["data"])
print(data["data"][0]["datum"]["image"]["pose"]["translation"]["x"])
print(data["data"][0]["datum"]["image"]["pose"]["rotation"])

print(data["data"][0]["datum"]["image"]["height"])
# Out:
# [{'next_key': '', 'datum': {'image': {'pose': {'translation': {'x': -28.439796447753906, 'y': -27.986038208007812, 'z': 14.385936737060547}, 'rotation': {'qw': -0.22373016758146114, 'qx': 0.9645359719625761, 'qy': 0.13678641060579783, 'qz': -0.030077379835383198}}, 'filename': 'rgb/compact_sport_01-000/000000000000000005.png', 'annotations': {'0': 'bounding_box_2d/compact_sport_01-000/000000000000000005_1680e62f1ad60d18a208599a5e617e013355204e.json', '1': 'bounding_box_3d/compact_sport_01-000/000000000000000005_486a5767638fc35dd15ec8bc6ae8648daa423da0.json', '2': 'semantic_segmentation_2d/compact_sport_01-000/000000000000000005.png', '4': 'instance_segmentation_2d/compact_sport_01-000/000000000000000005.png', '6': 'depth/compact_sport_01-000/000000000000000005.npz', '10': 'surface_normals_2d/compact_sport_01-000/000000000000000005.png'}, 'metadata': {}, 'height': 480, 'width': 640, 'channels': 4}}, 'id': {'timestamp': '2022-12-02T08:29:22.165000Z', 'index': '0', 'log': '', 'name': 'c
# ...
