# %%
# Import the necessary libraries
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a figure and a 3D axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Define the coordinates of the vertices of the cubes
red_cube_vertices = [[0,0,0], [0,1,0], [1,1,0], [1,0,0],
                     [0,0,1], [0,1,1], [1,1,1], [1,0,1]]
blue_cube_vertices = [[2,0,0], [2,1,0], [3,1,0], [3,0,0],
                      [2,0,1], [2,1,1], [3,1,1], [3,0,1]]

# Plot the red cube
ax.plot([red_cube_vertices[0][0], red_cube_vertices[1][0]],
        [red_cube_vertices[0][1], red_cube_vertices[1][1]],
        [red_cube_vertices[0][2], red_cube_vertices[1][2]],
        'r')
ax.plot([red_cube_vertices[0][0], red_cube_vertices[3][0]],
        [red_cube_vertices[0][1], red_cube_vertices[3][1]],
        [red_cube_vertices[0][2], red_cube_vertices[3][2]],
        'r')
ax.plot([red_cube_vertices[0][0], red_cube_vertices[4][0]],
        [red_cube_vertices[0][1], red_cube_vertices[4][1]],
        [red_cube_vertices[0][2], red_cube_vertices[4][2]],
        'r')
ax.plot([red_cube_vertices[1][0], red_cube_vertices[2][0]],
        [red_cube_vertices[1][1], red_cube_vertices[2][1]],
        [red_cube_vertices[1][2], red_cube_vertices[2][2]],
        'r')
ax.plot([red_cube_vertices[1][0], red_cube_vertices[5][0]],
        [red_cube_vertices[1][1], red_cube_vertices[5][1]],
        [red_cube_vertices[1][2], red_cube_vertices[5][2]],
        'r')
ax.plot([red_cube_vertices[2][0], red_cube_vertices[3][0]],
        [red_cube_vertices[2][1], red_cube_vertices[3][1]],
        [red_cube_vertices[2][2], red_cube_vertices[3][2]],
        'r')
ax.plot([red_cube_vertices[2][0], red_cube_vertices[6][0]],
        [red_cube_vertices[2][1], red_cube_vertices[6][1]],
        [red_cube_vertices[2][2], red_cube_vertices[6][2]],
        'r')
ax.plot([red_cube_vertices[3][0], red_cube_vertices[7][0]],
        [red_cube_vertices[3][1], red_cube_vertices[7][1]],
        [red_cube_vertices[3][2], red_cube_vertices[7][2]],
        'r')
ax.plot([red_cube_vertices[4][0], red_cube_vertices[5][0]],
        [red_cube_vertices[4][1], red_cube_vertices[5][1]],
        [red_cube_vertices[4][2], red_cube_vertices[5][2]],
        'r')
